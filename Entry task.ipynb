# %%
# File location and type
file_location = "/FileStore/tables/test_task_dataset_summer_products.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a view or table

temp_table_name = "test_task_dataset_summer_products_csv"

df.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql

/* Query the created temp table in a SQL cell */
create table summer_products as 
select * from `test_task_dataset_summer_products_csv`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
permanent_table_name = "summer_products"

df.write.format("parquet").saveAsTable(permanent_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1867834608675017&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> permanent_table_name <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;summer_products&#34;</span>
# <span class="ansi-green-intense-fg ansi-bold">      2</span>
# ...

# %%
# %sql
select
  avg(price),
  (sum(rating_five_count) / sum(rating_count)) * 100 as five_percentage,
  origin_country
from
  summer_products
group by
  origin_country
order by
  origin_country
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql import functions as F

res_df = df.select('price','origin_country','rating_five_count','rating_count').groupby('origin_country')\
      .agg(F.avg('price'), F.sum('rating_five_count').alias('sum_rating_five_count'), F.sum('rating_count').alias('sum_rating_count') )\
      .withColumn('five_percentage', F.col('sum_rating_five_count')/F.col('sum_rating_count')*100)\
      .orderBy('origin_country').drop('sum_rating_five_count').drop('sum_rating_count')

display(res_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>origin_country</th><th>avg(price)</th><th>five_percentage</th></tr></thead><tbody><tr><td>null</td><td>5.549411764705883</td><td>42.32593217919193</td></tr><tr><td>AT</td><td>7.0</td><td>null</td></tr><tr><td>CN</td><td>8.340099075297214</td><td>48.502801806612545</td></tr><tr><td>GB</td><td>9.0</td><td>51.20967741935484</td></tr><tr><td>SG</td><td>3.38</td><td>42.18036529680365</td></tr><tr><td>US</td><td>9.397096774193548</td><td>49.57595410326765</td></tr><tr><td>VE</td><td>8.298</td><td>47.61904761904761</td></tr><tr><td>hwalee</td><td>null</td><td>null</td></tr></tbody></table></div>
